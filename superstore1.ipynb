# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Superstore.csv', encoding = 'latin-1')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.describe(include = 'all')
# Out:
#              Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# count   9994.000000            9994       9994        9994            9994
# unique          NaN            5009       1237        1334               4
# top             NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq            NaN              14         38          35            5968
# mean    4997.500000             NaN        NaN         NaN             NaN
# std     2885.163629             NaN        NaN         NaN             NaN
# min        1.000000             NaN        NaN         NaN             NaN
# 25%     2499.250000             NaN        NaN         NaN             NaN
# 50%     4997.500000             NaN        NaN         NaN             NaN
# 75%     7495.750000             NaN        NaN         NaN             NaN
# max     9994.000000             NaN        NaN         NaN             NaN
#
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date']).dt.date

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date']).dt.date

# %%
df['Sales'] = df['Sales'].astype(int)

# %%
df['Profit'] = df['Profit'].astype(int)

# %%
df['Discount'] = (df['Discount']*100)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date        object
# Ship Date         object
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales              int64
# Quantity           int64
# Discount         float64
# Profit             int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Quarter'] = pd.to_datetime(df['Order Date']).dt.quarter

# %%
df['Duration of delivery'] = df['Ship Date'] - df['Order Date']

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df['Duration of delivery'].dtype
# Out:
# dtype('O')

# %%
df['Duration of delivery '] = pd.to_timedelta(df['Duration of delivery']).dt.days

# %%
df['Duration of delivery'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                     str
# Order Date                object
# Ship Date                 object
# Ship Mode                    str
# Customer ID                  str
# Customer Name                str
# Segment                      str
# Country                      str
# City                         str
# State                        str
# Postal Code                int64
# Region                       str
# Product ID                   str
# Category                     str
# Sub-Category                 str
# Product Name                 str
# Sales                      int64
# Quantity                   int64
# Discount                 float64
# Profit                     int64
# Quarter                    int32
# Duration of delivery      object
# Duration of delivery       int64
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df['Order Date'].dtype
# Out:
# dtype('<M8[s]')

# %%
df['Delivery duration'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Quarter',
#        'Duration of delivery ', 'Delivery duration'],
#       dtype='str')

# %%
df.drop(['Duration of delivery '],axis =1,inplace = True)

# %%
df.dtypes
# Out:
# Row ID                       int64
# Order ID                       str
# Order Date           datetime64[s]
# Ship Date            datetime64[s]
# Ship Mode                      str
# Customer ID                    str
# Customer Name                  str
# Segment                        str
# Country                        str
# City                           str
# State                          str
# Postal Code                  int64
# Region                         str
# Product ID                     str
# Category                       str
# Sub-Category                   str
# Product Name                   str
# Sales                        int64
# Quantity                     int64
# Discount                   float64
# Profit                       int64
# Quarter                      int32
# Delivery duration            int64
# dtype: object

# %%
df.describe()
# Out:
#             Row ID           Order Date            Ship Date   Postal Code  \
# count  9994.000000                 9994                 9994   9994.000000
# mean   4997.500000  2016-04-30 00:07:12  2016-05-03 23:06:58  55190.379428
# min       1.000000  2014-01-03 00:00:00  2014-01-07 00:00:00   1040.000000
# 25%    2499.250000  2015-05-23 00:00:00  2015-05-27 00:00:00  23223.000000
# 50%    4997.500000  2016-06-26 00:00:00  2016-06-29 00:00:00  56430.500000
# 75%    7495.750000  2017-05-14 00:00:00  2017-05-18 00:00:00  90008.000000
# max    9994.000000  2017-12-30 00:00:00  2018-01-05 00:00:00  99301.000000
# std    2885.163629                  NaN                  NaN  32063.693350
#
#               Sales     Quantity     Discount       Profit      Quarter  \
# count   9994.000000  9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.267961     3.789574    15.620272    28.335301     2.882329
# min        0.000000     1.000000     0.000000 -6599.000000     1.000000
# ...

# %%
Q1 = df.Quarter.quantile(0.25)
Q1
# Out:
# np.float64(2.0)

# %%
Q3 = df.Quarter.quantile(0.75)
Q3
# Out:
# np.float64(4.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(2.0)

# %%
lower_limit = Q1-(1.5*IQR)
lower_limit
# Out:
# np.float64(-1.0)

# %%
upper_limit = Q3+(1.5*IQR)
upper_limit
# Out:
# np.float64(7.0)

# %%
df[(df.Quarter<lower_limit) | (df.Quarter>upper_limit)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Quarter, Delivery duration]
# Index: []
#
# [0 rows x 23 columns]

# %%
sns.boxplot(x='Sales', data = df)
plt.show()

# %%
print(df['Sales'].nlargest(10))
# Out:
# 2697    22638
# 6826    17499
# 8153    13999
# 2623    11199
# 4190    10499
# 9039     9892
# 4098     9449
# 4277     9099
# 8488     8749
# 6425     8399
# Name: Sales, dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit', 'quarter',
#        'delivery_duration'],
#       dtype='str')

# %%
df = df.rename(columns={'sub-category':'sub_category'})

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit', 'quarter',
#        'delivery_duration'],
#       dtype='str')

# %%
df.dtypes
# Out:
# row_id                       int64
# order_id                       str
# order_date           datetime64[s]
# ship_date            datetime64[s]
# ship_mode                      str
# customer_id                    str
# customer_name                  str
# segment                        str
# country                        str
# city                           str
# state                          str
# postal_code                  int64
# region                         str
# product_id                     str
# category                       str
# sub-category                   str
# product_name                   str
# sales                        int64
# quantity                     int64
# discount                   float64
# profit                       int64
# quarter                      int32
# delivery_duration            int64
# dtype: object

# %%
from sqlalchemy import create_engine
engine = create_engine(
     "mysql+pymysql://root:root@localhost:3306/superstore_data")
with engine.connect() as conn:
    print("connected")
# Out:
# connected

# %%
from sqlalchemy.types import VARCHAR,INT,FLOAT,DOUBLE,DATE,DATETIME,DECIMAL,BIGINT

sql_types = {
'row_id'          : BIGINT(),
'order_id'        : VARCHAR(100),
'order_date'      : DATETIME(),
'ship_date'       : DATETIME(),    
'ship_mode'       : VARCHAR(100),
'customer_id'     : VARCHAR(100),              
'customer_name'   : VARCHAR(100),               
'segment'         : VARCHAR(100),               
'country'         :VARCHAR(100),               
'city'            : VARCHAR(100),               
'state'           :VARCHAR(100),               
'postal_code'     :INT(),             
'region'          : VARCHAR(100),               
'product_id'      : VARCHAR(100),               
'category'       : VARCHAR(100),                
'sub_category'   : VARCHAR(100),                
'product_name'   : VARCHAR(255),                
'sales'          : BIGINT(),               
'quantity'       :BIGINT(),               
'discount'       :DECIMAL(10,2),            
'profit'        : BIGINT(),                
'quarter'        : INT(),               
'delivery_duration' : INT() 
}  

df.to_sql(
    name='superstore_table',
    con=engine,
    if_exists='replace',
    index=False,
    dtype=sql_types)
# Out:
# 9994

# %%
df.to_sql(
    name='superstore_table',
    con=engine,
    if_exists='replace',
    index=False)
# Out:
# 9994
